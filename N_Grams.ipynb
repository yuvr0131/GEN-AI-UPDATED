# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvr0131/GEN-AI-UPDATED/blob/main/N_Grams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import ngrams

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def generate_ngrams(txt,n):
  tokens=word_tokenize(txt)
  n_grams=list(ngrams(tokens,n))
  return n_grams

# %%
#text
txt="N-Grams are a sequence of n items from a given sample of text or speech"
unigrams=generate_ngrams(txt,1)
bigrams=generate_ngrams(txt,2)
trigrams=generate_ngrams(txt,3)

# %%
print("Unigrams: ",unigrams)
print("Bigrams: ",bigrams)
print("Trigrams: ",trigrams)
# Out:
# Unigrams:  [('N-Grams',), ('are',), ('a',), ('sequence',), ('of',), ('n',), ('items',), ('from',), ('a',), ('given',), ('sample',), ('of',), ('text',), ('or',), ('speech',)]
# Bigrams:  [('N-Grams', 'are'), ('are', 'a'), ('a', 'sequence'), ('sequence', 'of'), ('of', 'n'), ('n', 'items'), ('items', 'from'), ('from', 'a'), ('a', 'given'), ('given', 'sample'), ('sample', 'of'), ('of', 'text'), ('text', 'or'), ('or', 'speech')]
# Trigrams:  [('N-Grams', 'are', 'a'), ('are', 'a', 'sequence'), ('a', 'sequence', 'of'), ('sequence', 'of', 'n'), ('of', 'n', 'items'), ('n', 'items', 'from'), ('items', 'from', 'a'), ('from', 'a', 'given'), ('a', 'given', 'sample'), ('given', 'sample', 'of'), ('sample', 'of', 'text'), ('of', 'text', 'or'), ('text', 'or', 'speech')]
