# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvr0131/GEN-AI-UPDATED/blob/main/NLP_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
txt="HELLO WORLD, how are YOU!"

# %%
x=txt.casefold()
print(x)
# Out:
# hello world, how are you!

# %%
y=txt.lower()
print(y)
# Out:
# hello world, how are you!

# %%
#
